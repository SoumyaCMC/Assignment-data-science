# %%
# !sudo for i in  $(pip list --outdated --format=columns |tail -n +3|cut -d" " -f1); do pip install $i --upgrade; done

# %%
import pkg_resources
from subprocess import call

packages = [dist.project_name for dist in pkg_resources.working_set]
call("pip install --upgrade " + ' '.join(packages), shell=True)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: zope.interface in /home/ashish/.local/lib/python3.8/site-packages (5.4.0)
# Requirement already satisfied: zipp in /home/ashish/.local/lib/python3.8/site-packages (3.5.0)
# Collecting zipp
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: wordcloud in /home/ashish/.local/lib/python3.8/site-packages (1.8.1)
# Requirement already satisfied: wikipedia in /home/ashish/.local/lib/python3.8/site-packages (1.4.0)
# Requirement already satisfied: widgetsnbextension in /home/ashish/.local/lib/python3.8/site-packages (3.5.1)
# Requirement already satisfied: wheel in /home/ashish/.local/lib/python3.8/site-packages (0.37.0)
# Requirement already satisfied: websocket-client in /home/ashish/.local/lib/python3.8/site-packages (1.2.1)
# Requirement already satisfied: webencodings in /home/ashish/.local/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: wcwidth in /home/ashish/.local/lib/python3.8/site-packages (0.2.5)
# Requirement already satisfied: wadllib in /home/ashish/.local/lib/python3.8/site-packages (1.3.6)
# Requirement already satisfied: urllib3 in /home/ashish/.local/lib/python3.8/site-packages (1.26.7)
# Requirement already satisfied: uritemplate in /home/ashish/.local/lib/python3.8/site-packages (3.0.1)
# Requirement already satisfied: typing-extensions in /home/ashish/.local/lib/python3.8/site-packages (3.10.0.2)
# Requirement already satisfied: txt2tags in /home/ashish/.local/lib/python3.8/site-packages (3.7)
# Requirement already satisfied: Twisted in /home/ashish/.local/lib/python3.8/site-packages (21.7.0)
# Requirement already satisfied: traitlets in /home/ashish/.local/lib/python3.8/site-packages (5.1.0)
# Requirement already satisfied: tornado in /home/ashish/.local/lib/python3.8/site-packages (6.1)
# Requirement already satisfied: torchvision in /home/ashish/.local/lib/python3.8/site-packages (0.10.0)
# Collecting torchvision
#   Downloading torchvision-0.10.1-cp38-cp38-manylinux1_x86_64.whl (22.1 MB)
# Requirement already satisfied: torchaudio in /home/ashish/.local/lib/python3.8/site-packages (0.9.0)
# Collecting torchaudio
#   Downloading torchaudio-0.9.1-cp38-cp38-manylinux1_x86_64.whl (1.9 MB)
# Requirement already satisfied: torch in /home/ashish/.local/lib/python3.8/site-packages (1.9.0)
# Collecting torch
#   Downloading torch-1.9.1-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
# Requirement already satisfied: testresources in /home/ashish/.local/lib/python3.8/site-packages (2.0.1)
# Requirement already satisfied: testpath in /home/ashish/.local/lib/python3.8/site-packages (0.5.0)
# Requirement already satisfied: terminado in /home/ashish/.local/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: tenacity in /home/ashish/.local/lib/python3.8/site-packages (8.0.1)
# Requirement already satisfied: sqlparse in /home/ashish/.local/lib/python3.8/site-packages (0.4.2)
# Requirement already satisfied: SQLAlchemy in /home/ashish/.local/lib/python3.8/site-packages (1.4.25)
# Requirement already satisfied: soupsieve in /home/ashish/.local/lib/python3.8/site-packages (2.2.1)
# Requirement already satisfied: sniffio in /home/ashish/.local/lib/python3.8/site-packages (1.2.0)
# Requirement already satisfied: smmap in /home/ashish/.local/lib/python3.8/site-packages (4.0.0)
# Requirement already satisfied: six in /home/ashish/.local/lib/python3.8/site-packages (1.16.0)
# Requirement already satisfied: simplejson in /home/ashish/.local/lib/python3.8/site-packages (3.17.5)
# Requirement already satisfied: setuptools in /home/ashish/.local/lib/python3.8/site-packages (58.1.0)
# Requirement already satisfied: setproctitle in /home/ashish/.local/lib/python3.8/site-packages (1.2.2)
# Requirement already satisfied: service-identity in /home/ashish/.local/lib/python3.8/site-packages (21.1.0)
# Requirement already satisfied: Send2Trash in /home/ashish/.local/lib/python3.8/site-packages (1.8.0)
# Requirement already satisfied: SecretStorage in /home/ashish/.local/lib/python3.8/site-packages (3.3.1)
# Requirement already satisfied: scipy in /home/ashish/.local/lib/python3.8/site-packages (1.7.1)
# Requirement already satisfied: rsa in /home/ashish/.local/lib/python3.8/site-packages (4.7.2)
# Requirement already satisfied: rise in /home/ashish/.local/lib/python3.8/site-packages (5.7.1)
# Requirement already satisfied: requests in /home/ashish/.local/lib/python3.8/site-packages (2.26.0)
# Requirement already satisfied: reportlab in /home/ashish/.local/lib/python3.8/site-packages (3.6.1)
# Requirement already satisfied: QtPy in /home/ashish/.local/lib/python3.8/site-packages (1.11.2)
# Requirement already satisfied: qtconsole in /home/ashish/.local/lib/python3.8/site-packages (5.1.1)
# Requirement already satisfied: pyzmq in /home/ashish/.local/lib/python3.8/site-packages (22.3.0)
# Requirement already satisfied: PyYAML in /home/ashish/.local/lib/python3.8/site-packages (5.4.1)
# Requirement already satisfied: pyxdg in /home/ashish/.local/lib/python3.8/site-packages (0.27)
# Requirement already satisfied: pytz in /home/ashish/.local/lib/python3.8/site-packages (2021.1)
# Requirement already satisfied: python-debian in /home/ashish/.local/lib/python3.8/site-packages (0.1.40)
# Requirement already satisfied: python-dateutil in /home/ashish/.local/lib/python3.8/site-packages (2.8.2)
# Requirement already satisfied: pyrsistent in /home/ashish/.local/lib/python3.8/site-packages (0.18.0)
# Requirement already satisfied: pyparsing in /home/ashish/.local/lib/python3.8/site-packages (2.4.7)
# Requirement already satisfied: pyOpenSSL in /home/ashish/.local/lib/python3.8/site-packages (21.0.0)
# Requirement already satisfied: PyNaCl in /home/ashish/.local/lib/python3.8/site-packages (1.4.0)
# Requirement already satisfied: PyJWT in /home/ashish/.local/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: PyHamcrest in /home/ashish/.local/lib/python3.8/site-packages (2.0.2)
# Requirement already satisfied: Pygments in /home/ashish/.local/lib/python3.8/site-packages (2.10.0)
# Requirement already satisfied: pygame in /home/ashish/.local/lib/python3.8/site-packages (2.0.1)
# Requirement already satisfied: pycparser in /home/ashish/.local/lib/python3.8/site-packages (2.20)
# Requirement already satisfied: pyasn1 in /home/ashish/.local/lib/python3.8/site-packages (0.4.8)
# Requirement already satisfied: pyasn1-modules in /home/ashish/.local/lib/python3.8/site-packages (0.2.8)
# Requirement already satisfied: ptyprocess in /home/ashish/.local/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: protobuf in /home/ashish/.local/lib/python3.8/site-packages (3.18.0)
# Requirement already satisfied: prompt-toolkit in /home/ashish/.local/lib/python3.8/site-packages (3.0.20)
# Requirement already satisfied: prometheus-client in /home/ashish/.local/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: plotly in /home/ashish/.local/lib/python3.8/site-packages (5.3.1)
# Requirement already satisfied: pip in /home/ashish/.local/lib/python3.8/site-packages (21.2.4)
# Requirement already satisfied: Pillow in /home/ashish/.local/lib/python3.8/site-packages (8.3.2)
# Requirement already satisfied: pickleshare in /home/ashish/.local/lib/python3.8/site-packages (0.7.5)
# Requirement already satisfied: pexpect in /home/ashish/.local/lib/python3.8/site-packages (4.8.0)
# Requirement already satisfied: pbr in /home/ashish/.local/lib/python3.8/site-packages (5.6.0)
# Requirement already satisfied: parso in /home/ashish/.local/lib/python3.8/site-packages (0.8.2)
# Requirement already satisfied: paramiko in /home/ashish/.local/lib/python3.8/site-packages (2.7.2)
# Requirement already satisfied: pandocfilters in /home/ashish/.local/lib/python3.8/site-packages (1.5.0)
# Requirement already satisfied: pandas in /home/ashish/.local/lib/python3.8/site-packages (1.3.3)
# Requirement already satisfied: packaging in /home/ashish/.local/lib/python3.8/site-packages (21.0)
# Requirement already satisfied: openpyxl in /home/ashish/.local/lib/python3.8/site-packages (3.0.9)
# Requirement already satisfied: oauthlib in /home/ashish/.local/lib/python3.8/site-packages (3.1.1)
# Requirement already satisfied: oauth2client in /home/ashish/.local/lib/python3.8/site-packages (4.1.3)
# Requirement already satisfied: numpy in /home/ashish/.local/lib/python3.8/site-packages (1.21.2)
# Requirement already satisfied: numpy-financial in /home/ashish/.local/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: notebook in /home/ashish/.local/lib/python3.8/site-packages (6.4.4)
# Requirement already satisfied: netifaces in /home/ashish/.local/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: nest-asyncio in /home/ashish/.local/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: nbformat in /home/ashish/.local/lib/python3.8/site-packages (5.1.3)
# Requirement already satisfied: nbconvert in /home/ashish/.local/lib/python3.8/site-packages (6.2.0)
# Requirement already satisfied: nbclient in /home/ashish/.local/lib/python3.8/site-packages (0.5.4)
# Requirement already satisfied: nbclassic in /home/ashish/.local/lib/python3.8/site-packages (0.3.2)
# Requirement already satisfied: monotonic in /home/ashish/.local/lib/python3.8/site-packages (1.6)
# Requirement already satisfied: mistune in /home/ashish/.local/lib/python3.8/site-packages (0.8.4)
# Requirement already satisfied: matplotlib in /home/ashish/.local/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: matplotlib-inline in /home/ashish/.local/lib/python3.8/site-packages (0.1.3)
# Requirement already satisfied: MarkupSafe in /home/ashish/.local/lib/python3.8/site-packages (2.0.1)
# Requirement already satisfied: Mako in /home/ashish/.local/lib/python3.8/site-packages (1.1.5)
# Requirement already satisfied: lckr-jupyterlab-variableinspector in /home/ashish/.local/lib/python3.8/site-packages (3.0.9)
# Requirement already satisfied: lazr.uri in /home/ashish/.local/lib/python3.8/site-packages (1.0.6)
# Requirement already satisfied: lazr.restfulclient in /home/ashish/.local/lib/python3.8/site-packages (0.14.4)
# Requirement already satisfied: launchpadlib in /home/ashish/.local/lib/python3.8/site-packages (1.10.14)
# Requirement already satisfied: lab in /home/ashish/.local/lib/python3.8/site-packages (6.5)
# Requirement already satisfied: kiwisolver in /home/ashish/.local/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: keyring in /home/ashish/.local/lib/python3.8/site-packages (23.2.1)
# Requirement already satisfied: jupyterlab in /home/ashish/.local/lib/python3.8/site-packages (3.1.14)
# Requirement already satisfied: jupyterlab-widgets in /home/ashish/.local/lib/python3.8/site-packages (1.0.2)
# Requirement already satisfied: jupyterlab-server in /home/ashish/.local/lib/python3.8/site-packages (2.8.2)
# Requirement already satisfied: jupyterlab-pygments in /home/ashish/.local/lib/python3.8/site-packages (0.1.2)
# Requirement already satisfied: jupyterlab-gitplus in /home/ashish/.local/lib/python3.8/site-packages (0.3.2)
# Requirement already satisfied: jupyterlab-github in /home/ashish/.local/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: jupyter in /home/ashish/.local/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: jupyter-server in /home/ashish/.local/lib/python3.8/site-packages (1.11.0)
# Requirement already satisfied: jupyter-core in /home/ashish/.local/lib/python3.8/site-packages (4.8.1)
# Requirement already satisfied: jupyter-console in /home/ashish/.local/lib/python3.8/site-packages (6.4.0)
# Requirement already satisfied: jupyter-client in /home/ashish/.local/lib/python3.8/site-packages (7.0.5)
# Requirement already satisfied: jsonschema in /home/ashish/.local/lib/python3.8/site-packages (4.0.0)
# Requirement already satisfied: json5 in /home/ashish/.local/lib/python3.8/site-packages (0.9.6)
# Requirement already satisfied: Jinja2 in /home/ashish/.local/lib/python3.8/site-packages (3.0.1)
# Requirement already satisfied: jeepney in /home/ashish/.local/lib/python3.8/site-packages (0.7.1)
# Requirement already satisfied: jedi in /home/ashish/.local/lib/python3.8/site-packages (0.18.0)
# Requirement already satisfied: ipywidgets in /home/ashish/.local/lib/python3.8/site-packages (7.6.5)
# Requirement already satisfied: ipython in /home/ashish/.local/lib/python3.8/site-packages (7.28.0)
# Requirement already satisfied: ipython-genutils in /home/ashish/.local/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: ipykernel in /home/ashish/.local/lib/python3.8/site-packages (6.4.1)
# Requirement already satisfied: incremental in /home/ashish/.local/lib/python3.8/site-packages (21.3.0)
# Requirement already satisfied: importlib-metadata in /home/ashish/.local/lib/python3.8/site-packages (4.8.1)
# Requirement already satisfied: idna in /home/ashish/.local/lib/python3.8/site-packages (3.2)
# Requirement already satisfied: hyperlink in /home/ashish/.local/lib/python3.8/site-packages (21.0.0)
# Requirement already satisfied: httplib2 in /home/ashish/.local/lib/python3.8/site-packages (0.19.1)
# Requirement already satisfied: greenlet in /home/ashish/.local/lib/python3.8/site-packages (1.1.2)
# Requirement already satisfied: googleapis-common-protos in /home/ashish/.local/lib/python3.8/site-packages (1.53.0)
# Requirement already satisfied: google-auth in /home/ashish/.local/lib/python3.8/site-packages (2.2.1)
# Requirement already satisfied: google-auth-httplib2 in /home/ashish/.local/lib/python3.8/site-packages (0.1.0)
# Requirement already satisfied: google-api-python-client in /home/ashish/.local/lib/python3.8/site-packages (2.23.0)
# Requirement already satisfied: google-api-core in /home/ashish/.local/lib/python3.8/site-packages (2.0.1)
# Requirement already satisfied: GitPython in /home/ashish/.local/lib/python3.8/site-packages (3.1.24)
# Requirement already satisfied: gitdb in /home/ashish/.local/lib/python3.8/site-packages (4.0.7)
# Requirement already satisfied: fasteners in /home/ashish/.local/lib/python3.8/site-packages (0.16.3)
# Requirement already satisfied: et-xmlfile in /home/ashish/.local/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: Django in /home/ashish/.local/lib/python3.8/site-packages (3.2.7)
# Requirement already satisfied: distro in /home/ashish/.local/lib/python3.8/site-packages (1.6.0)
# Requirement already satisfied: distro-info in /home/ashish/.local/lib/python3.8/site-packages (0.0.0)
# Collecting distro-info
#   Using cached distro_info-0.0.0-py3-none-any.whl
# Requirement already satisfied: defusedxml in /home/ashish/.local/lib/python3.8/site-packages (0.7.1)
# WARNING: Discarding https://files.pythonhosted.org/packages/91/e0/ccd731d32238bc18bb8ac80353b4028394f80d5ff7db0f93a5ba488690d3/distro-info-0.10.tar.gz#sha256=3c5c2c800e84f36e56e4c59b09981eae357127494f9eb391712888c3f7ac2916 (from https://pypi.org/simple/distro-info/). Requested distro-info from file:///home/ashish/.cache/pip/wheels/70/41/44/7433bd9e251aed01842961adf793059948d1de98d25877c5b8/distro_info-0.0.0-py3-none-any.whl has inconsistent version: filename has '0.10', but metadata has '0.0.0'
# Requirement already satisfied: decorator in /home/ashish/.local/lib/python3.8/site-packages (5.1.0)
# Requirement already satisfied: debugpy in /home/ashish/.local/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: cycler in /home/ashish/.local/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: cryptography in /home/ashish/.local/lib/python3.8/site-packages (35.0.0)
# Requirement already satisfied: colorama in /home/ashish/.local/lib/python3.8/site-packages (0.4.4)
# Requirement already satisfied: click in /home/ashish/.local/lib/python3.8/site-packages (8.0.1)
# Requirement already satisfied: charset-normalizer in /home/ashish/.local/lib/python3.8/site-packages (2.0.6)
# Requirement already satisfied: chardet in /home/ashish/.local/lib/python3.8/site-packages (4.0.0)
# Requirement already satisfied: cffi in /home/ashish/.local/lib/python3.8/site-packages (1.14.6)
# Requirement already satisfied: certifi in /home/ashish/.local/lib/python3.8/site-packages (2021.5.30)
# Requirement already satisfied: cachetools in /home/ashish/.local/lib/python3.8/site-packages (4.2.4)
# Requirement already satisfied: bleach in /home/ashish/.local/lib/python3.8/site-packages (4.1.0)
# Requirement already satisfied: beautifulsoup4 in /home/ashish/.local/lib/python3.8/site-packages (4.10.0)
# Requirement already satisfied: bcrypt in /home/ashish/.local/lib/python3.8/site-packages (3.2.0)
# Requirement already satisfied: backcall in /home/ashish/.local/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: Babel in /home/ashish/.local/lib/python3.8/site-packages (2.9.1)
# Requirement already satisfied: Automat in /home/ashish/.local/lib/python3.8/site-packages (20.2.0)
# Requirement already satisfied: attrs in /home/ashish/.local/lib/python3.8/site-packages (21.2.0)
# Requirement already satisfied: async-generator in /home/ashish/.local/lib/python3.8/site-packages (1.10)
# Requirement already satisfied: asgiref in /home/ashish/.local/lib/python3.8/site-packages (3.4.1)
# Requirement already satisfied: argon2-cffi in /home/ashish/.local/lib/python3.8/site-packages (21.1.0)
# Requirement already satisfied: anyio in /home/ashish/.local/lib/python3.8/site-packages (3.3.2)
# Requirement already satisfied: speedtest-cli in /usr/local/lib/python3.8/dist-packages (2.1.3)
# Requirement already satisfied: xkit in /usr/lib/python3/dist-packages (0.0.0)
# Requirement already satisfied: usb-creator in /usr/lib/python3/dist-packages (0.3.7)
# Requirement already satisfied: unattended-upgrades in /usr/lib/python3/dist-packages (0.1)
# Requirement already satisfied: ufw in /usr/lib/python3/dist-packages (0.36)
# Requirement already satisfied: ubuntu-drivers-common in /usr/lib/python3/dist-packages (0.0.0)
# Requirement already satisfied: ubuntu-advantage-tools in /usr/lib/python3/dist-packages (27.2)
# Requirement already satisfied: systemd-python in /usr/lib/python3/dist-packages (234)
# Requirement already satisfied: screen-resolution-extra in /usr/lib/python3/dist-packages (0.0.0)
# Requirement already satisfied: requests-unixsocket in /usr/lib/python3/dist-packages (0.2.0)
# Requirement already satisfied: rencode in /usr/lib/python3/dist-packages (1.0.6)
# Requirement already satisfied: python-libtorrent in /usr/lib/python3/dist-packages (1.1.13)
# Requirement already satisfied: python-apt in /usr/lib/python3/dist-packages (2.0.0+ubuntu0.20.4.6)
# Requirement already satisfied: pyRFC3339 in /usr/lib/python3/dist-packages (1.1)
# Requirement already satisfied: pymacaroons in /usr/lib/python3/dist-packages (0.13.0)
# Requirement already satisfied: PyGObject in /usr/lib/python3/dist-packages (3.36.0)
# Collecting PyGObject
#   Using cached PyGObject-3.42.0.tar.gz (716 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached PyGObject-3.40.1.tar.gz (714 kB)
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 /tmp/pip-standalone-pip-brboglwt/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-kceu0szy/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (38 lines):
#   Collecting setuptools
#     Using cached setuptools-58.1.0-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 /tmp/tmp57m0buli build_wheel /tmp/tmpwbvmh1em
#          cwd: /tmp/pip-install-bdomr289/pycairo_da060e5b5c354c12810d54ca0d98e15d
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.py -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.pyi -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/py.typed -> build/lib.linux-x86_64-3.8/cairo
#     running build_ext
#     Package cairo was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `cairo.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'cairo' found
#     Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/cc/72/48cfdd7a0caf3c27f392d2657731ac6f7c3c1c0a60bfeba3e1ba9ffa7ba9/PyGObject-3.42.0.tar.gz#sha256=b9803991ec0b0b4175e81fee0ad46090fa7af438fe169348a9b18ae53447afcd (from https://pypi.org/simple/pygobject/) (requires-python:>=3.6, <4). Command errored out with exit status 1: /usr/bin/python3 /tmp/pip-standalone-pip-brboglwt/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-kceu0szy/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached PyGObject-3.40.0.tar.gz (714 kB)
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 /tmp/pip-standalone-pip-08a0njcj/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-u1ekjyvc/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (38 lines):
#   Collecting setuptools
#     Using cached setuptools-58.1.0-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 /tmp/tmp4tzraq_c build_wheel /tmp/tmpb53z44q4
#          cwd: /tmp/pip-install-6o2_0s5p/pycairo_8e7ac023b81b458c9d56d861791ad338
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.py -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.pyi -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/py.typed -> build/lib.linux-x86_64-3.8/cairo
#     running build_ext
#     Package cairo was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `cairo.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'cairo' found
#     Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/51/2f/4d5d5afb7000b9151e33952b59163c9389bd867ac6fe85d62f85831fa061/PyGObject-3.40.1.tar.gz#sha256=6fb599aa59ceb9dd05fafb0d72b3862943e7d5e85c8ef6c74856bc6d4321cbab (from https://pypi.org/simple/pygobject/) (requires-python:>=3.6, <4). Command errored out with exit status 1: /usr/bin/python3 /tmp/pip-standalone-pip-08a0njcj/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-u1ekjyvc/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached PyGObject-3.38.0.tar.gz (712 kB)
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 /tmp/pip-standalone-pip-2fkt3sd6/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-1ldg17cl/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (38 lines):
#   Collecting setuptools
#     Using cached setuptools-58.1.0-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 /tmp/tmp5u5x89d9 build_wheel /tmp/tmp_er3jm2s
#          cwd: /tmp/pip-install-tblz2r8k/pycairo_019e87f3ce3a4672bbd67a4ff3bf02ea
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.py -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.pyi -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/py.typed -> build/lib.linux-x86_64-3.8/cairo
#     running build_ext
#     Package cairo was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `cairo.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'cairo' found
#     Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/fa/0cfaa64ad7a4cd94fd74b698fcc8987ed780fce1651fecc6604f86f604cd/PyGObject-3.40.0.tar.gz#sha256=98d83f71e6313dadc29793450fec23b2eaa5c3f1c4b073d0a4f9c31b5cdb5fca (from https://pypi.org/simple/pygobject/) (requires-python:>=3.6, <4). Command errored out with exit status 1: /usr/bin/python3 /tmp/pip-standalone-pip-2fkt3sd6/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-1ldg17cl/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached PyGObject-3.36.1.tar.gz (716 kB)
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 /tmp/pip-standalone-pip-mfzu9o3p/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-ioscgvkc/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (38 lines):
#   Collecting setuptools
#     Using cached setuptools-58.1.0-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 /tmp/tmp599l6awb build_wheel /tmp/tmpc6mils77
#          cwd: /tmp/pip-install-tng9_pj7/pycairo_771e6862d0a949878ebcc30cdd5b73ba
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.py -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.pyi -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/py.typed -> build/lib.linux-x86_64-3.8/cairo
#     running build_ext
#     Package cairo was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `cairo.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'cairo' found
#     Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/a7/de282a4aaedba59d60a895a7821e6497b39cbdfa94a352776ff45ffc6e6f/PyGObject-3.38.0.tar.gz#sha256=051b950f509f2e9f125add96c1493bde987c527f7a0c15a1f7b69d6d1c3cd8e6 (from https://pypi.org/simple/pygobject/) (requires-python:>=3.5, <4). Command errored out with exit status 1: /usr/bin/python3 /tmp/pip-standalone-pip-mfzu9o3p/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-ioscgvkc/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Requirement already satisfied: PyDrive in /usr/lib/python3/dist-packages (1.3.1)
# Requirement already satisfied: pycups in /usr/lib/python3/dist-packages (1.9.73)
# Collecting pycups
#   Using cached pycups-2.0.1.tar.gz (62 kB)
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 /tmp/pip-standalone-pip-pgv6vd4d/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-s3a28cyj/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (38 lines):
#   Collecting setuptools
#     Using cached setuptools-58.1.0-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 /tmp/tmp2kzjpf20 build_wheel /tmp/tmp6_eqapvh
#          cwd: /tmp/pip-install-wdcjnn42/pycairo_863444752ee64a539c5efa3ba10570c8
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.py -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/__init__.pyi -> build/lib.linux-x86_64-3.8/cairo
#     copying cairo/py.typed -> build/lib.linux-x86_64-3.8/cairo
#     running build_ext
#     Package cairo was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `cairo.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'cairo' found
#     Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/93/41/bf9ab8929f51dac2979ae81bb094728bacee3ceb049def72d3fc1bcb4241/PyGObject-3.36.1.tar.gz#sha256=012a589aec687bfa809a1ff9f5cd775dc7f6fcec1a6bc7fe88e1002a68f8ba34 (from https://pypi.org/simple/pygobject/) (requires-python:>=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, !=3.4.*, <4). Command errored out with exit status 1: /usr/bin/python3 /tmp/pip-standalone-pip-pgv6vd4d/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-s3a28cyj/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
# Requirement already satisfied: pycairo in /usr/lib/python3/dist-packages (1.16.2)
# Collecting pycairo
#   Using cached pycairo-1.20.1.tar.gz (344 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: olefile in /usr/lib/python3/dist-packages (0.46)
# Requirement already satisfied: macaroonbakery in /usr/lib/python3/dist-packages (1.3.1)
# Requirement already satisfied: louis in /usr/lib/python3/dist-packages (3.12.0)
# Requirement already satisfied: lockfile in /usr/lib/python3/dist-packages (0.12.2)
# Requirement already satisfied: language-selector in /usr/lib/python3/dist-packages (0.1)
# Requirement already satisfied: GeoIP in /usr/lib/python3/dist-packages (1.3.2)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (0.18.2)
# Requirement already satisfied: entrypoints in /usr/lib/python3/dist-packages (0.3)
# Requirement already satisfied: duplicity in /usr/lib/python3/dist-packages (0.8.12.0)
# Collecting duplicity
#   Using cached duplicity-0.8.20.tar.gz (1.4 MB)
# Requirement already satisfied: deluge in /usr/lib/python3/dist-packages (2.0.3)
# Requirement already satisfied: defer in /usr/lib/python3/dist-packages (1.0.6)
# Requirement already satisfied: dbus-python in /usr/lib/python3/dist-packages (1.2.16)
# Requirement already satisfied: cupshelpers in /usr/lib/python3/dist-packages (1.0)
# Requirement already satisfied: constantly in /usr/lib/python3/dist-packages (15.1.0)
# Requirement already satisfied: command-not-found in /usr/lib/python3/dist-packages (0.3)
# Requirement already satisfied: Brlapi in /usr/lib/python3/dist-packages (0.7.0)
# Requirement already satisfied: blinker in /usr/lib/python3/dist-packages (1.4)
# Requirement already satisfied: apturl in /usr/lib/python3/dist-packages (0.5.2)
# Collecting jupyterlab
#   Downloading jupyterlab-3.2.0b0-py3-none-any.whl (8.6 MB)
# Building wheels for collected packages: pycups, pycairo, duplicity
#   Building wheel for pycups (setup.py): started
#   Building wheel for pycups (setup.py): finished with status 'error'
#   Running setup.py clean for pycups
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-dlszvk60/pycups_daed593369984fd69690ab52b9596213/setup.py'"'"'; __file__='"'"'/tmp/pip-install-dlszvk60/pycups_daed593369984fd69690ab52b9596213/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-yt4gu0la
#        cwd: /tmp/pip-install-dlszvk60/pycups_daed593369984fd69690ab52b9596213/
#   Complete output (12 lines):
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'cups' extension
#   creating build
#   creating build/temp.linux-x86_64-3.8
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DVERSION="2.0.1" -I/usr/include/python3.8 -c cupsmodule.c -o build/temp.linux-x86_64-3.8/cupsmodule.o
#   cupsmodule.c:24:10: fatal error: cups/cups.h: No such file or directory
#      24 | #include <cups/cups.h>
#         |          ^~~~~~~~~~~~~
#   compilation terminated.
#   error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pycups
#   Building wheel for pycairo (PEP 517): started
#   Building wheel for pycairo (PEP 517): finished with status 'error'
#   Building wheel for duplicity (setup.py): started
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 /home/ashish/.local/lib/python3.8/site-packages/pip/_vendor/pep517/in_process/_in_process.py build_wheel /tmp/tmpebbsoao4
#        cwd: /tmp/pip-install-dlszvk60/pycairo_4c562252e23e4ad4b68a1be2f6863ce7
#   Complete output (15 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.8
#   creating build/lib.linux-x86_64-3.8/cairo
#   copying cairo/__init__.py -> build/lib.linux-x86_64-3.8/cairo
#   copying cairo/__init__.pyi -> build/lib.linux-x86_64-3.8/cairo
#   copying cairo/py.typed -> build/lib.linux-x86_64-3.8/cairo
#   running build_ext
#   Package cairo was not found in the pkg-config search path.
#   Perhaps you should add the directory containing `cairo.pc'
#   to the PKG_CONFIG_PATH environment variable
#   No package 'cairo' found
#   Command '['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']' returned non-zero exit status 1.
#   ----------------------------------------
#   ERROR: Failed building wheel for pycairo
#   Building wheel for duplicity (setup.py): finished with status 'error'
#   Running setup.py clean for duplicity
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-dlszvk60/duplicity_df425e36345c477793b28e1e2b23a0dd/setup.py'"'"'; __file__='"'"'/tmp/pip-install-dlszvk60/duplicity_df425e36345c477793b28e1e2b23a0dd/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-3sn627_1
#        cwd: /tmp/pip-install-dlszvk60/duplicity_df425e36345c477793b28e1e2b23a0dd/
#   Complete output (201 lines):
#   Unable to get SCM version: defaulting to 0.8.20
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.8
#   creating build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/dup_main.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/filechunkio.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/robust.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/dup_threading.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/gpginterface.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/dup_time.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/dup_temp.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/errors.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/diffdir.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/manifest.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/statistics.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/tempdir.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/path.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/file_naming.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/cached_ops.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/tarfile.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/lazy.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/log.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/backend.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/selection.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/patchdir.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/config.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/dup_collections.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/progress.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/commandline.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/globmatch.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/asyncscheduler.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/librsync.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/__init__.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/gpg.py -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/util.py -> build/lib.linux-x86_64-3.8/duplicity
#   creating build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/onedrivebackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/ncftpbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/tahoebackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/b2backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/ssh_paramiko_backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/multibackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/dpbxbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/_boto_multi.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/gdocsbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/hsibackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/giobackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/jottacloudbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/imapbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/idrivedbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/rclonebackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/pydrivebackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/megav3backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/s3_boto3_backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/megav2backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/pcabackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/hubicbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/cfbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/sxbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/boxbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/lftpbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/rsyncbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/swiftbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/par2backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/megabackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/webdavbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/azurebackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/__init__.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/_boto_single.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/_cf_pyrax.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/gdrivebackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/localbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/adbackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/_cf_cloudfiles.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/s3_boto_backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/ssh_pexpect_backend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying duplicity/backends/mediafirebackend.py -> build/lib.linux-x86_64-3.8/duplicity/backends
#   creating build/lib.linux-x86_64-3.8/duplicity/backends/pyrax_identity
#   copying duplicity/backends/pyrax_identity/__init__.py -> build/lib.linux-x86_64-3.8/duplicity/backends/pyrax_identity
#   copying duplicity/backends/pyrax_identity/hubic.py -> build/lib.linux-x86_64-3.8/duplicity/backends/pyrax_identity
#   creating build/lib.linux-x86_64-3.8/testing
#   copying testing/find_unadorned_strings.py -> build/lib.linux-x86_64-3.8/testing
#   copying testing/test_code.py -> build/lib.linux-x86_64-3.8/testing
#   copying testing/__init__.py -> build/lib.linux-x86_64-3.8/testing
#   copying testing/fix_unadorned_strings.py -> build/lib.linux-x86_64-3.8/testing
#   copying testing/conftest.py -> build/lib.linux-x86_64-3.8/testing
#   creating build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/__init__.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_restart.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_replicate.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_log.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_selection.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_rdiffdir.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_cleanup.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_final.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_verify.py -> build/lib.linux-x86_64-3.8/testing/functional
#   copying testing/functional/test_badupload.py -> build/lib.linux-x86_64-3.8/testing/functional
#   creating build/lib.linux-x86_64-3.8/testing/overrides
#   copying testing/overrides/__init__.py -> build/lib.linux-x86_64-3.8/testing/overrides
#   creating build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/__init__.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_dup_temp.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_manifest.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_path.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_dup_time.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_backend.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_gpginterface.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_statistics.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_collections.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_diffdir.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_backend_instance.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_selection.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_patchdir.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_util.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_tarfile.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_globmatch.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_file_naming.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_lazy.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_tempdir.py -> build/lib.linux-x86_64-3.8/testing/unit
#   copying testing/unit/test_gpg.py -> build/lib.linux-x86_64-3.8/testing/unit
#   running egg_info
#   writing duplicity.egg-info/PKG-INFO
#   writing dependency_links to duplicity.egg-info/dependency_links.txt
#   writing requirements to duplicity.egg-info/requires.txt
#   writing top-level names to duplicity.egg-info/top_level.txt
#   listing git files failed - pretending there aren't any
#   reading manifest file 'duplicity.egg-info/SOURCES.txt'
#   adding license file 'COPYING'
#   adding license file 'AUTHORS'
#   writing manifest file 'duplicity.egg-info/SOURCES.txt'
#   copying duplicity/_librsyncmodule.c -> build/lib.linux-x86_64-3.8/duplicity
#   copying duplicity/backends/README -> build/lib.linux-x86_64-3.8/duplicity/backends
#   copying testing/run-tests -> build/lib.linux-x86_64-3.8/testing
#   copying testing/testfiles.tar.gz -> build/lib.linux-x86_64-3.8/testing
#   creating build/lib.linux-x86_64-3.8/testing/docker
#   copying testing/docker/.env -> build/lib.linux-x86_64-3.8/testing/docker
#   copying testing/docker/build-duplicity_test.sh -> build/lib.linux-x86_64-3.8/testing/docker
#   copying testing/docker/docker-compose.yml -> build/lib.linux-x86_64-3.8/testing/docker
#   copying testing/docker/id_rsa -> build/lib.linux-x86_64-3.8/testing/docker
#   copying testing/docker/id_rsa.pub -> build/lib.linux-x86_64-3.8/testing/docker
#   copying testing/docker/setup.sh -> build/lib.linux-x86_64-3.8/testing/docker
#   copying testing/docker/teardown.sh -> build/lib.linux-x86_64-3.8/testing/docker
#   creating build/lib.linux-x86_64-3.8/testing/docker/duplicity_test
#   copying testing/docker/duplicity_test/Dockerfile-18.04 -> build/lib.linux-x86_64-3.8/testing/docker/duplicity_test
#   copying testing/docker/duplicity_test/Dockerfile-18.10 -> build/lib.linux-x86_64-3.8/testing/docker/duplicity_test
#   copying testing/docker/duplicity_test/Dockerfile-19.04 -> build/lib.linux-x86_64-3.8/testing/docker/duplicity_test
#   copying testing/docker/duplicity_test/Dockerfile-19.10 -> build/lib.linux-x86_64-3.8/testing/docker/duplicity_test
#   copying testing/docker/duplicity_test/Dockerfile-20.04 -> build/lib.linux-x86_64-3.8/testing/docker/duplicity_test
#   creating build/lib.linux-x86_64-3.8/testing/docker/ftp_server
#   copying testing/docker/ftp_server/Dockerfile -> build/lib.linux-x86_64-3.8/testing/docker/ftp_server
#   copying testing/docker/ftp_server/pureftpd.passwd -> build/lib.linux-x86_64-3.8/testing/docker/ftp_server
#   creating build/lib.linux-x86_64-3.8/testing/docker/ssh_server
#   copying testing/docker/ssh_server/Dockerfile -> build/lib.linux-x86_64-3.8/testing/docker/ssh_server
#   creating build/lib.linux-x86_64-3.8/testing/gnupg
#   copying testing/gnupg/README -> build/lib.linux-x86_64-3.8/testing/gnupg
#   copying testing/gnupg/gpg-agent.conf -> build/lib.linux-x86_64-3.8/testing/gnupg
#   copying testing/gnupg/gpg.conf -> build/lib.linux-x86_64-3.8/testing/gnupg
#   copying testing/gnupg/pubring.gpg -> build/lib.linux-x86_64-3.8/testing/gnupg
#   copying testing/gnupg/secring.gpg -> build/lib.linux-x86_64-3.8/testing/gnupg
#   copying testing/gnupg/trustdb.gpg -> build/lib.linux-x86_64-3.8/testing/gnupg
#   creating build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/__init__.py -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/auto-ctrl-c-test.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/backendtest.py -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/bug1526557.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/bug1846678.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/bug1860200.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/bug1893481.tgz -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/bug1919017.json -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/bug1919017.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/bug487720.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/issue25.json -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/issue25.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/issue26.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/manual-ctrl-c-test.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/rootfiles.tar.gz -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/roottest.py -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/run-coverage.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/stdin_test.sh -> build/lib.linux-x86_64-3.8/testing/manual
#   copying testing/manual/test_config.py.tmpl -> build/lib.linux-x86_64-3.8/testing/manual
#   creating build/lib.linux-x86_64-3.8/testing/overrides/bin
#   copying testing/overrides/bin/hsi -> build/lib.linux-x86_64-3.8/testing/overrides/bin
#   copying testing/overrides/bin/lftp -> build/lib.linux-x86_64-3.8/testing/overrides/bin
#   copying testing/overrides/bin/ncftpget -> build/lib.linux-x86_64-3.8/testing/overrides/bin
#   copying testing/overrides/bin/ncftpls -> build/lib.linux-x86_64-3.8/testing/overrides/bin
#   copying testing/overrides/bin/ncftpput -> build/lib.linux-x86_64-3.8/testing/overrides/bin
#   copying testing/overrides/bin/tahoe -> build/lib.linux-x86_64-3.8/testing/overrides/bin
#   running build_ext
#   Building extension for librsync...
#   building 'duplicity._librsync' extension
#   creating build/temp.linux-x86_64-3.8
#   creating build/temp.linux-x86_64-3.8/duplicity
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c duplicity/_librsyncmodule.c -o build/temp.linux-x86_64-3.8/duplicity/_librsyncmodule.o
#   duplicity/_librsyncmodule.c:28:10: fatal error: librsync.h: No such file or directory
#      28 | #include <librsync.h>
#         |          ^~~~~~~~~~~~
#   compilation terminated.
#   error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for duplicity
# Failed to build pycups pycairo duplicity
# ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
# 1
